# %%
# general formula for a circle
# (y-k)**2 + (x - h)**2 = r**2

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
h = 2
k = -3
r = 3




axlim = r + np.max((abs(h),abs(k)))
x = np.linspace(-axlim,axlim,100)

X,Y = np.meshgrid(x,x)

# Fxy = (X-h)**2 + (Y-k)**2 = r**2
Fxy = (X-h)**2 + (Y-k)**2 -r**2

plt.contour(X,Y,Fxy,0)
plt.plot([-axlim,axlim],[0,0],'k--')
plt.plot([0,0],[-axlim,axlim],'k--')
plt.plot(h,k,'go')

# plt.axis('square')
plt.gca().set_aspect('equal')
plt.show()

# %%
# exercise.imdependend
# h = 2
h = 1.5
k = 0
r = np.linspace(.5,3,10)

# netative function
for i in range(len(r)):
    Fxy = (X-h)**2 + (Y-k)**2 -r[i]**2
    Fxy2 = (X+h)**2 + (Y-k)**2 -r[i]**2
    plt.contour(X,Y,Fxy,0)
    plt.contour(X,Y,Fxy2,0)
    
#positive function
# for i in range(len(r)):
#     Fxy = (X-h)**2 + (Y-k)**2 +r[i]**2
#     plt.contour(X,Y,Fxy,0)

# plt.contour(X,Y,Fxy,0)
plt.gca().set_aspect('equal')
plt.show()
radii
# Out:
# [1, 2, 3, 4]

# %%
# exercise.instructed
h = [-1.5,1.5]

x = np.linspace(-5,5,100)
X,Y = np.meshgrid(x,x)

for r in np.linspace(.5,3,15):
    for hi in h:
        Fxy = (X-hi)**2 + Y**2 - r**2
        plt.contour(X,Y,Fxy,0,colors=[r/3,r/3,r/3])

plt.axis('off')
plt.gca().set_aspect('equal')
plt.plot(h,[0,0],'k',linewidth=3)
plt.show()

# %%
# experimental
plt.contour(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-33a2e3caf188> in <module>
#       1 # experimental
# ----> 2 hi
#
# NameError: name 'hi' is not defined

# %%
Fxy = (X-h)**2 + (Y-k)**2 -r**2
plt.imshow(Fxy)
